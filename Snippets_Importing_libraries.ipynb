# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthurrodopia/Arthurrodopia.github.io/blob/main/Snippets_Importing_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing a library that is not in Colaboratory
#
# To import a library that's not in Colaboratory by default, you can use `!pip install` or `!apt-get install`.

# %%
5
# Out:
# 5

# %%
print(5)
# Out:
# 5

# %%
print('ola mundo')
# Out:
# ola mundo

# %% [markdown]
# começando aula de pythonn

# %%
print('ola mundo'  ' 5')
# Out:
# ola mundo 5

# %%
5+2
# Out:
# 7

# %%
produto1 = 5

# %%
print(produto1)
# Out:
# 5

# %%
produto2 = 2000

# %%
print(produto2 )
# Out:
# 2000

# %%
produto3 = 30

# %%
print(produto1 + produto2 + produto3
      )
# Out:
# 2035

# %%
nome_do_produto1 = 'arroz'
nome_do_produto2 = 'celular'
nome_do_produto3 = 'bala'

# %%
print(nome_do_produto1 +   "" + "  " +  nome_do_produto2 +  "" + "  " + nome_do_produto3)
# Out:
# arroz  celular  bala

# %%
amigos = 5
aluguel = 900
supermercado = 500
carro = 200

# %%
total = aluguel + supermercado + carro

# %%
print(total
      )
# Out:
# 1600

# %%
aluguel = aluguel - 100

# %%
print(aluguel)
# Out:
# 600

# %%
amigos = 6
aluguel = 900
supermercado = 500
carro = 200

# %%
print(amigos)
# Out:
# 6

# %%
print(carro * 2)
# Out:
# 400

# %%
total_de_carros = carro * 2

# %%
print(total_de_carros)
# Out:
# 400

# %%
total = aluguel + supermercado + total_de_carros
print(total)
# Out:
# 1800

# %%
total_por_pessoas = total / amigos
print(total_por_pessoas)
# Out:
# 300.0

# %%
type(aluguel)

# %%
type(total_por_pessoa)

# %%
type(nome_do_produto1)

# %%
pedro_tem_carteira_de_motorista = True
mario_tem_carteira_de_motorista = False

# %%
type(mario_tem_carteira_de_motorista)

# %%
texto = "   Fabrício CARRaro  da alura   "

# %%
print(texto)

# %%
print(texto.lower())

# %% [markdown]
# #Estruturas de dados

# %%
lista_de_nomes = ["Alice Oliveira", "Bruno Silva","Camila Souza","Diego Fernandes","Elena Martins"
]

# %%
print(lista_de_nomes[1])
# Out:
# Bruno Silva

# %%
lista_de_medias = [10,9,8,7,6]

# %%
print(lista_de_medias[2])
# Out:
# 8

# %% [markdown]
# desaio loop while

# %%
n = 0

while n <= 5:
 lista_de_medias[n] = lista_de_medias[n] + 1.0
 if lista_de_medias[n] > 10:
  lista_de_medias[n]= 10.0

n = n + 1

print(lista_de_medias)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-419163465.py in <cell line: 0>()
#       1 n = 0
#       2
# ----> 3 while n <= 5:
#       4  lista_de_medias[n] = lista_de_medias[n] + 1.0
#       5  if lista_de_medias[n] > 10:
#
# KeyboardInterrupt:
