# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthurrodopia/Arthurrodopia.github.io/blob/main/Aula02_completa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 2

# %% [markdown]
# ### Rodando a sua IA no Google Colab

# %%
import os
from google.colab import userdata

# Por favor, certifique-se de que 'GEMINI_API_KEY_2' esteja configurado nos seus Segredos do Colab
# Se o seu segredo tiver outro nome, substitua 'GEMINI_API_KEY_2' pelo nome correto.
os.environ["GOOGLE_API_KEY"] = userdata.get('alura')

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ.get('alura'))

# %%
resposta = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="O que é a Inteligência Artificial?"
    )
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-3375219163.py in <cell line: 0>()
# ----> 1 resposta = client.models.generate_content(
#       2     model="gemini-2.5-flash",
#       3     contents="O que é a Inteligência Artificial?"
#       4     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5228     while remaining_remote_calls_afc > 0:
#    5229       i += 1
# -> 5230       response = self._generate_content(
#    5231           model=model, contents=contents, config=parsed_config
#    5232       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4010     request_dict = _common.encode_unserializable_types(request_dict)
#    4011
# -> 4012     response = self._api_client.request(
#    4013         'post', path, request_dict, http_options
#    4014     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1386         http_method, path, request_dict, http_options
#    1387     )
# -> 1388     response = self._request(http_request, http_options, stream=False)
#    1389     response_body = (
#    1390         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1222         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1223
# -> 1224     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1225
#    1226   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     475         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     376         result = None
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#     380
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                 retry_exc = self.retry_error_cls(fut)
#     419                 if self.reraise:
# --> 420                     raise retry_exc.reraise()
#     421                 raise retry_exc from fut.exception()
#     422
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     185     def reraise(self) -> t.NoReturn:
#     186         if self.last_attempt.failed:
# --> 187             raise self.last_attempt.result()
#     188         raise self
#     189
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#     482                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1199           timeout=http_request.timeout,
#    1200       )
# -> 1201       errors.APIError.raise_for_response(response)
#    1202       return HttpResponse(
#    1203           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     119       response_json = response.body_segments[0].get('error', {})
#     120
# --> 121     cls.raise_error(response.status_code, response_json, response)
#     122
#     123   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     144     """
#     145     if 400 <= status_code < 500:
# --> 146       raise ClientError(status_code, response_json, response)
#     147     elif 500 <= status_code < 600:
#     148       raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %%
print(resposta.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4189310853.py in <cell line: 0>()
# ----> 1 print(resposta.text)
#
# NameError: name 'resposta' is not defined

# %% [markdown]
# ### Estruturas de Repetição, Loops, Laços

# %%
print("***************")
# Out:
# ***************

# %%
n = 1

while n <= 10:
    print("*")
    n = n + 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
resposta = chat.send_message("O que é a Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)**, ou Artificial Intelligence (AI) em inglês, é um campo da ciência da computação focado na criação de máquinas ou sistemas que podem simular e reproduzir capacidades cognitivas tipicamente associadas à inteligência humana.
#
# Em termos mais simples, a IA busca desenvolver computadores e softwares que possam **aprender, raciocinar, resolver problemas, perceber, compreender a linguagem humana e tomar decisões**, tal como um ser humano faria, mas muitas vezes em escalas e velocidades muito maiores.
#
# **Componentes e Conceitos Chave da IA:**
#
# 1.  **Aprendizagem (Machine Learning - ML):** É a base da maioria das IAs modernas. Permite que os sistemas aprendam com dados, identifiquem padrões e tomem decisões ou previsões sem serem explicitamente programados para cada tarefa.
#     *   **Deep Learning (Aprendizagem Profunda):** Um subcampo do Machine Learning que utiliza redes neurais artificiais com múltiplas camadas (profundas) para processar grandes volumes de dados e reconhecer padrões complexos (imagens, voz, texto).
#
# 2.  **Processamento de Linguagem Natural (PLN/NLP):** A capacidade de computadores entenderem, interpretarem e gerarem linguagem humana (escrita ou falada). Exemplos incluem assistentes virtuais, tradutores automáticos e chatbots.
#
# 3.  **Visão Computacional:** Permite que os computadores "vejam" e interpretem imagens e vídeos do mundo real, reconhecendo objetos, rostos, cenas e até emoções. Usado em carros autônomos, reconhecimento facial e análise médica.
#
# 4.  **Raciocínio e Resolução de Problemas:** Sistemas que podem usar lógica e algoritmos para resolver problemas complexos, planejar ações e tomar decisões.
#
# 5.  **Percepção:** A capacidade de um sistema de IA de interpretar dados sensoriais (como áudio ou vídeo) do ambiente para entender o que está acontecendo.
#
# 6.  **Robótica:** Embora a IA e a Robótica sejam campos distintos, a IA frequentemente é o "cérebro" por trás de robôs autônomos, permitindo que eles percebam seu ambiente, tomem decisões e executem tarefas complexas.
#
# **Tipos de Inteligência Artificial:**
#
# Geralmente, a IA é categorizada em três níveis, embora a maioria do que vemos hoje se enquadre no primeiro:
#
# 1.  **IA Fraca ou Estreita (Narrow AI / Weak AI):** É a IA projetada e treinada para uma tarefa específica. Ex: sistemas de recomendação, assistentes de voz (Siri, Alexa), carros autônomos, reconhecimento facial. A maioria das aplicações de IA atuais se encaixa aqui.
# 2.  **IA Geral (General AI / Strong AI):** Uma IA que pode compreender, aprender e aplicar sua inteligência a qualquer problema, assim como um ser humano. É uma IA com capacidade cognitiva ampla. Atualmente, a IA geral é um objetivo de pesquisa e não existe na prática.
# 3.  **Super IA (Super AI):** Uma IA que excede a inteligência humana em todos os aspectos, incluindo criatividade, resolução de problemas e habilidades sociais. Isso é um conceito puramente teórico e especulativo.
#
# **Exemplos Práticos de IA no Dia a Dia:**
#
# *   **Assistentes Virtuais:** Siri, Google Assistant, Alexa.
# *   **Sistemas de Recomendação:** Netflix (filmes), Amazon (produtos), Spotify (músicas).
# *   **Carros Autônomos:** Tesla, Waymo.
# *   **Filtros de Spam e Detecção de Fraudes:** Em e-mails e transações bancárias.
# *   **Reconhecimento Facial:** Desbloqueio de smartphones, segurança.
# *   **Chatbots e Atendimento ao Cliente:** Em websites e aplicativos.
# *   **Geração de Conteúdo:** Ferramentas como o ChatGPT (texto) e DALL-E (imagens).
# *   **Diagnósticos Médicos:** Auxiliando médicos na identificação de doenças.
#
# A Inteligência Artificial é um campo em constante evolução, com o potencial de transformar praticamente todos os aspectos da nossa vida e da sociedade.

# %%
resposta = chat.send_message("Quando foi lançado o ChatGPT?")
print(resposta.text)
# Out:
# O ChatGPT foi lançado em **30 de novembro de 2022** pela OpenAI.

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='O que é a Inteligência Artificial?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""A **Inteligência Artificial (IA)**, ou Artificial Intelligence (AI) em inglês, é um campo da ciência da computação focado na criação de máquinas ou sistemas que podem simular e reproduzir capacidades cognitivas tipicamente associadas à inteligência humana.
#
#  Em termos mais simples, a IA busca desenvolver computadores e softwares que possam **aprender, raciocinar, resolver problemas, perceber, compreender a linguagem humana e tomar decisões**, tal como um ser humano faria, mas muitas vezes em escalas e velocidades muito maiores.
#
#  **Componentes e Conceitos Chave da IA:**
#
#  1.  **Aprendizagem (Machine Learning - ML):** É a base da maioria das IAs modernas. Permite que os sistemas aprendam com dados, identifiquem padrões e tomem decisões ou previsões sem serem explicitamente programados para cada tarefa.
#      *   **Deep Learning (Aprendizagem Profunda):** Um subcampo do Machine Learning que utiliza redes neurais artificiais com múltiplas camadas (profundas) para processar grandes volumes de dados e reconhecer padrões complexos (imagens, voz, texto).
#
#  2.  **Processamento de Linguagem Natural (PLN/NLP):** A capacidade de computadores entenderem, interpretarem e gerarem linguagem humana (escrita ou falada). Exemplos incluem assistentes virtuais, tradutores automáticos e chatbots.
#
#  3.  **Visão Computacional:** Permite que os computadores "vejam" e interpretem imagens e vídeos do mundo real, reconhecendo objetos, rostos, cenas e até emoções. Usado em carros autônomos, reconhecimento facial e análise médica.
#
#  4.  **Raciocínio e Resolução de Problemas:** Sistemas que podem usar lógica e algoritmos para resolver problemas complexos, planejar ações e tomar decisões.
#
#  5.  **Percepção:** A capacidade de um sistema de IA de interpretar dados sensoriais (como áudio ou vídeo) do ambiente para entender o que está acontecendo.
#
#  6.  **Robótica:** Embora a IA e a Robótica sejam campos distintos, a IA frequentemente é o "cérebro" por trás de robôs autônomos, permitindo que eles percebam seu ambiente, tomem decisões e executem tarefas complexas.
#
#  **Tipos de Inteligência Artificial:**
#
#  Geralmente, a IA é categorizada em três níveis, embora a maioria do que vemos hoje se enquadre no primeiro:
#
#  1.  **IA Fraca ou Estreita (Narrow AI / Weak AI):** É a IA projetada e treinada para uma tarefa específica. Ex: sistemas de recomendação, assistentes de voz (Siri, Alexa), carros autônomos, reconhecimento facial. A maioria das aplicações de IA atuais se encaixa aqui.
#  2.  **IA Geral (General AI / Strong AI):** Uma IA que pode compreender, aprender e aplicar sua inteligência a qualquer problema, assim como um ser humano. É uma IA com capacidade cognitiva ampla. Atualmente, a IA geral é um objetivo de pesquisa e não existe na prática.
#  3.  **Super IA (Super AI):** Uma IA que excede a inteligência humana em todos os aspectos, incluindo criatividade, resolução de problemas e habilidades sociais. Isso é um conceito puramente teórico e especulativo.
#
#  **Exemplos Práticos de IA no Dia a Dia:**
#
#  *   **Assistentes Virtuais:** Siri, Google Assistant, Alexa.
#  *   **Sistemas de Recomendação:** Netflix (filmes), Amazon (produtos), Spotify (músicas).
#  *   **Carros Autônomos:** Tesla, Waymo.
#  *   **Filtros de Spam e Detecção de Fraudes:** Em e-mails e transações bancárias.
#  *   **Reconhecimento Facial:** Desbloqueio de smartphones, segurança.
#  *   **Chatbots e Atendimento ao Cliente:** Em websites e aplicativos.
#  *   **Geração de Conteúdo:** Ferramentas como o ChatGPT (texto) e DALL-E (imagens).
#  *   **Diagnósticos Médicos:** Auxiliando médicos na identificação de doenças.
#
#  A Inteligência Artificial é um campo em constante evolução, com o potencial de transformar praticamente todos os aspectos da nossa vida e da sociedade."""
#      ),
#    ],
#    role='model'
#  ),
#  UserContent(
#    parts=[
#      Part(
#        text='Quando foi lançado o ChatGPT?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text='O ChatGPT foi lançado em **30 de novembro de 2022** pela OpenAI.'
#      ),
#    ],
#    role='model'
#  )]

# %%
prompt = input("Digite a sua pergunta: ")

while prompt != "fim":
    resposta = chat.send_message(prompt)
    print(resposta.text)
    print("\n")
    prompt = input("Digite a sua pergunta: ")
# Out:
# Digite a sua pergunta: Quem é você?
# Eu sou um modelo de linguagem grande, treinado pelo Google. Fui desenvolvido para ajudar com informações, gerar texto, responder perguntas e interagir de forma conversacional.
#
#
# Digite a sua pergunta: fim

# %% [markdown]
# ### Estruturas de dados

# %% [markdown]
# #### Listas

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
#                      0               1               2              3                4

# %%
print(lista_de_nomes[3])
# Out:
# Pedro Costa

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias)
# Out:
# [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias[3])
# Out:
# 1.4

# %% [markdown]
# Desafio: Crie um código que percorra a lista de médias e some 1 a cada valor, exceto quando o valor passar de 10.0, que aí ele deve parar em 10.0.

# %%
n = 0

while n < 5:
    lista_de_medias[n] = lista_de_medias[n] + 1.0
    if lista_de_medias[n] > 10.0:
        lista_de_medias[n] = 10.0

    n = n + 1

print(lista_de_medias)
# Out:
# [9.9, 8.5, 5.2, 2.4, 10.0]

# %%
len(lista_de_medias)
# Out:
# 5

# %%
n = 0

while n < len(lista_de_medias):
    lista_de_medias[n] = lista_de_medias[n] + 1.0
    if lista_de_medias[n] > 10.0:
        lista_de_medias[n] = 10.0

    n = n + 1

print(lista_de_medias)
# Out:
# [10.0, 9.5, 6.2, 3.4, 10.0]

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias)
# Out:
# [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
lista_de_medias[len(lista_de_medias) - 1]
# Out:
# 9.5

# %%
lista_de_medias[-1]
# Out:
# 9.5

# %%
lista_de_medias[-2]
# Out:
# 1.4

# %% [markdown]
# #### Particionando uma lista

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira']

# %%
lista_de_nomes[1:3]
# Out:
# ['João Santos', 'Ana Oliveira']

# %%
lista_de_nomes[1:4]
# Out:
# ['João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes[1:]
# Out:
# ['João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira']

# %%
lista_de_nomes[0:4]
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes[:4]
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira']

# %%
lista_de_nomes.append("Fábio Carraro")

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Fábio Carraro']

# %%
len(lista_de_nomes)
# Out:
# 6

# %%
lista_de_nomes.append("Joana da Silva", "Paulo Silveira")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2968458327.py in <cell line: 0>()
# ----> 1 lista_de_nomes.append("Joana da Silva", "Paulo Silveira")
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
lista_de_nomes.extend(["Joana da Silva", "Paulo Silveira"])

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Fábio Carraro',
#  'Joana da Silva',
#  'Paulo Silveira']

# %%
lista_de_nomes.append(["Márcio Costa", "Natália Pedreira"])

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Fábio Carraro',
#  'Joana da Silva',
#  'Paulo Silveira',
#  ['Márcio Costa', 'Natália Pedreira']]

# %%
lista_de_nomes[8]
# Out:
# ['Márcio Costa', 'Natália Pedreira']

# %%
lista_de_nomes[8][0]
# Out:
# 'Márcio Costa'

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
#                      0               1               2              3                4

# %%
lista_de_nomes.extend(["Joana da Silva", "Paulo Silveira"])

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Joana da Silva',
#  'Paulo Silveira']

# %%
lista_de_nomes.remove("Paulo Silveira")

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Joana da Silva']

# %%
lista_de_nomes.pop()
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira']

# %%
lista_de_nomes.pop(2)
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Pedro Costa', 'Juliana Pereira']

# %% [markdown]
# #### Dicionários<br>"chave":valor

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
dict_de_nomes_e_medias = {"Maria Silva":8.9,
                         "João Santos":7.5,
                         "Ana Oliveira":4.2,
                         "Pedro Costa":1.4,
                         "Juliana Pereira":9.5}

# %%
dict_de_nomes_e_medias["Maria Silva"]
# Out:
# 8.9

# %%
dict_de_nomes_e_medias.get("Maria Silva")
# Out:
# 8.9

# %%
dict_de_nomes_e_medias.pop("Juliana Pereira")
# Out:
# 9.5

# %%
dict_de_nomes_e_medias
# Out:
# {'Maria Silva': 8.9,
#  'João Santos': 7.5,
#  'Ana Oliveira': 4.2,
#  'Pedro Costa': 1.4}

# %%
dict_de_nomes_e_medias.items()
# Out:
# dict_items([('Maria Silva', 8.9), ('João Santos', 7.5), ('Ana Oliveira', 4.2), ('Pedro Costa', 1.4)])

# %%
dict_de_nomes_e_medias.keys()
# Out:
# dict_keys(['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa'])

# %%
dict_de_nomes_e_medias.values()
# Out:
# dict_values([8.9, 7.5, 4.2, 1.4])

# %% [markdown]
# Desafio: Usar dicionários de forma que as chaves sejam "nome" e "média", e os valores, sejam os nomes e médias dos alunos

# %%
dict_desafio = [
    {"nome": "Maria Silva", "média": 8.9},
    {"nome": "João Santos", "média": 7.5},
    {"nome": "Ana Oliveira", "média": 4.2},
    {"nome": "Pedro Costa", "média": 1.4}
]

# %%
dict_desafio[0]
# Out:
# {'nome': 'Maria Silva', 'média': 8.9}

# %%
dict_desafio[0]["média"]
# Out:
# 8.9

# %%
    texto1 = "aNa SiLvA"
    texto2 = "joÃO PeReIrA"
    texto3 = "MARia CoSta"
    texto4 = "PeDro SoUzA"
    texto5 = "luCaS AlMeIdA"

# %%
texto1.split()
# Out:
# ['aNa', 'SiLvA']

# %%
len(texto1.split())
# Out:
# 2

# %%
def escreve_texto_corretamente(texto):
  texto_novo = texto.upper()
  lista_de_palavras = texto_novo.split()
  nome_final = " ".join(lista_de_palavras)
  return nome_final

# %%
escreve_texto_corretamente(texto1)
# Out:
# ANA SILVA

# %%
escreve_texto_corretamente(texto2)
# Out:
# JOÃO PEREIRA

# %%
escreve_texto_corretamente(texto3)
# Out:
# MARIA COSTA

# %%
def escreve_texto_corretamente_alternativa(texto):
  print(" ".join(texto1.upper().split()))

# %%
escreve_texto_corretamente_alternativa(texto1)
# Out:
# ANA SILVA

# %%
salas_de_aula = ["sala 1", "sala 2", "sala 3"]

# %%
import random
def aloca_alunos_em_salas(nome_do_aluno, lista_de_salas):
  sala_do_aluno = random.choice(lista_de_salas)
  print(lista_de_salas)

  dict_aluno = {
      "nome": nome_do_aluno,
      "sala": sala_do_aluno
  }
  print(dict_aluno)

# %%
aloca_alunos_em_salas(texto1, salas_de_aula)
# Out:
# ['sala 1', 'sala 2', 'sala 3']
# {'nome': 'aNa SiLvA', 'sala': 'sala 3'}

# %%
nome_final = escreve_texto_corretamente(texto1)

# %%
texto1
# Out:
# 'aNa SiLvA'

# %%
nome_processado = escreve_texto_corretamente(texto1)
aloca_alunos_em_salas(nome_processado, salas_de_aula)
# Out:
# ['sala 1', 'sala 2', 'sala 3']
# {'nome': 'ANA SILVA', 'sala': 'sala 3'}

# %%
emails_corpos = [
    "Olá equipe, segue em anexo o relatório financeiro do mês para análise.",

    "Prezados alunos, lembramos que a prova de matemática será na próxima terça-feira.",

    "Bom dia, gostaria de confirmar a reserva do hotel para o final de semana.",

    "Caros clientes, temos uma promoção especial de eletrônicos válida até sexta-feira.",

    "Olá, envio aqui o cardápio atualizado para o evento de gastronomia.",

    "Prezados, segue a pauta da reunião de planejamento estratégico.",

    "Boa tarde, gostaria de agendar uma consulta médica para a próxima semana.",

    "Caros colegas, compartilho o link da pesquisa acadêmica sobre sustentabilidade.",

    "Olá, envio as fotos do ensaio fotográfico realizado ontem.",


]
# Out:
# Email 1: Olá equipe, segue em anexo o relatório financeiro do mês para análise.
# Email 2: Prezados alunos, lembramos que a prova de matemática será na próxima terça-feira.
# Email 3: Bom dia, gostaria de confirmar a reserva do hotel para o final de semana.
# Email 4: Caros clientes, temos uma promoção especial de eletrônicos válida até sexta-feira.
# Email 5: Olá, envio aqui o cardápio atualizado para o evento de gastronomia.
# Email 6: Prezados, segue a pauta da reunião de planejamento estratégico.
# Email 7: Boa tarde, gostaria de agendar uma consulta médica para a próxima semana.
# Email 8: Caros colegas, compartilho o link da pesquisa acadêmica sobre sustentabilidade.
# Email 9: Olá, envio as fotos do ensaio fotográfico realizado ontem.
# Email 10: Prezados, segue proposta de parceria para divulgação cultural.
# Email 11: Bom dia, lembramos que o campeonato de futebol começa neste sábado.
# Email 12: Caros participantes, envio o cronograma do curso de programação.
# Email 13: Prezados clientes, informamos que o prazo de entrega foi antecipado.
# Email 14: Olá equipe, segue atualização do projeto de design gráfico.
# Email 15: Boa tarde, envio os resultados da pesquisa de satisfação dos usuários.
# Email 16: Prezados, lembramos que o pagamento da mensalidade vence amanhã.
# Email 17: Caros amigos, compartilho a receita especial de bolo de chocolate.
# Email 18: Olá, envio o convite para a exposição de arte contemporânea.
# Email 19: Prezados, segue o manual de instruções do novo software.
# Email 20: Bom dia, envio a lista de materiais necessários para a oficina de artesanato.

# %%
def resumidor_de_email(lista_de_emails):
    for email in lista_de_emails:
     resposta = client.models.generate_content(
         model="gemini-2.5-flash",
            contents=f"""vou te mandar o corpo de um email quero que vc resuma passando o tema
             central de email: {email}"""
    )

     print(resposta.text)
     print("-" * 50)

# %%
resumidor_de_email(emails_corpos)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-1313695979.py in <cell line: 0>()
# ----> 1 resumidor_de_email(emails_corpos)
#
# /tmp/ipython-input-1396611642.py in resumidor_de_email(lista_de_emails)
#       1 def resumidor_de_email(lista_de_emails):
#       2     for email in lista_de_emails:
# ----> 3      resposta = client.models.generate_content(
#       4          model="gemini-2.5-flash",
#       5             contents=f"""vou te mandar o corpo de um email quero que vc resuma passando o tema
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5228     while remaining_remote_calls_afc > 0:
#    5229       i += 1
# -> 5230       response = self._generate_content(
#    5231           model=model, contents=contents, config=parsed_config
#    5232       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4010     request_dict = _common.encode_unserializable_types(request_dict)
#    4011
# -> 4012     response = self._api_client.request(
#    4013         'post', path, request_dict, http_options
#    4014     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1386         http_method, path, request_dict, http_options
#    1387     )
# -> 1388     response = self._request(http_request, http_options, stream=False)
#    1389     response_body = (
#    1390         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1222         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1223
# -> 1224     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1225
#    1226   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     475         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     376         result = None
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#     380
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                 retry_exc = self.retry_error_cls(fut)
#     419                 if self.reraise:
# --> 420                     raise retry_exc.reraise()
#     421                 raise retry_exc from fut.exception()
#     422
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     185     def reraise(self) -> t.NoReturn:
#     186         if self.last_attempt.failed:
# --> 187             raise self.last_attempt.result()
#     188         raise self
#     189
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#     482                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1199           timeout=http_request.timeout,
#    1200       )
# -> 1201       errors.APIError.raise_for_response(response)
#    1202       return HttpResponse(
#    1203           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     119       response_json = response.body_segments[0].get('error', {})
#     120
# --> 121     cls.raise_error(response.status_code, response_json, response)
#     122
#     123   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     144     """
#     145     if 400 <= status_code < 500:
# --> 146       raise ClientError(status_code, response_json, response)
#     147     elif 500 <= status_code < 600:
#     148       raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
